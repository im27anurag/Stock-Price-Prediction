# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import datetime, os
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inp0 = pd.read_csv('AAPL.csv')
inp0.shape
# Out:
# (2514, 6)

# %%
inp0.head(10)
# Out:
#         Date   Close    Open     High     Low   Volume
# 0  1/17/2020  138.31  136.54  138.330  136.16  5623336
# 1  1/16/2020  137.98  137.32  138.190  137.01  4320911
# 2  1/15/2020  136.62  136.00  138.055  135.71  4045952
# 3  1/14/2020  135.82  136.28  137.139  135.55  3683458
# 4  1/13/2020  136.60  135.48  136.640  135.07  3531572
# 5  1/10/2020  136.69  137.00  137.870  136.31  3255641
# 6   1/9/2020  136.74  135.74  136.790  135.31  3732830
# 7   1/8/2020  135.31  134.51  135.860  133.92  4346140
# 8   1/7/2020  134.19  133.69  134.960  133.40  3275968
# 9   1/6/2020  134.10  133.42  134.240  133.20  2426305

# %%
inp0.plot("Date", "Close")
plt.show()

# %%
inp0 = inp0.sort_index(ascending=False)
plt.figure(figsize=[15,6])
inp0.plot("Date", "Close")
plt.show()

# %%
ts_data = inp0.Close.values.reshape(-1,1)
plt.figure(figsize=[15,6])
plt.plot(ts_data)
plt.show()

# %%
print(ts_data)
# Out:
# [[126.12]
#  [125.75]
#  [126.33]
#  ...
#  [136.62]
#  [137.98]
#  [138.31]]

# %%
train_recs = int(len(ts_data) * 0.75)
train_data = ts_data[:train_recs]
test_data =ts_data[train_recs:]
len(train_data), len(test_data)
# Out:
# (1885, 629)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
def get_lookback(inp, look_back): 
    y = pd.DataFrame(inp)
    dataX = [y.shift(i) for i in range(1, look_back+1)]
    dataX = pd.concat(dataX, axis=1)
    dataX.fillna(0, inplace = True)
    return dataX.values, y.values

# %%
look_back = 10
trainX, trainY = get_lookback(train_scaled, look_back=look_back)
testX, testY = get_lookback(test_scaled, look_back= look_back)
trainY.shape, testY.shape
# Out:
# ((1885, 1), (629, 1))

# %% [markdown]
# ## Building a SimpleRNN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers \
import SimpleRNN, Activation, Dropout, Dense, Reshape,LSTM

model = Sequential()
model.add(Reshape((look_back,1), input_shape = (look_back,)))
model.add(SimpleRNN(32, input_shape=(look_back, 1)))
model.add(Dense(units=1, activation='linear' ))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 10, 1)             0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 32)                1088
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 1,121
# Trainable params: 1,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(trainX, trainY, epochs=3, batch_size=1, \
verbose=2, validation_split=0.1)
# Out:
# Epoch 1/3
# 1696/1696 - 8s - loss: 0.0033 - val_loss: 4.4983e-04
# Epoch 2/3
# 1696/1696 - 6s - loss: 0.0010 - val_loss: 0.0019
# Epoch 3/3
# 1696/1696 - 6s - loss: 9.5564e-04 - val_loss: 4.0941e-04

# %%
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
import math
def get_model_perf(model_obj):
    score_train = model_obj.evaluate(trainX, trainY, verbose=0)
    print('Train RMSE: %.2f RMSE' % (math.sqrt(score_train)))
    score_test = model_obj.evaluate(testX, testY, verbose=0)
    print('Test RMSE: %.2f RMSE' % (math.sqrt(score_test)))
    
get_model_perf(model)
# Out:
# Train RMSE: 0.02 RMSE
# Test RMSE: 0.03 RMSE

# %%
model.evaluate(trainX,trainY,verbose=0)
# Out:
# 0.0005598757998086512

# %%
def plot_pred(model_obj):
    testPredict = \
    scaler.inverse_transform(model_obj.predict(testX))
    pred_test_plot = ts_data.copy()
    pred_test_plot[:train_recs+look_back,:] = np.nan
    pred_test_plot[train_recs+look_back:,:] = \
    testPredict[look_back:]
    plt.plot(ts_data)
    plt.plot(pred_test_plot, "--")
    
# %matplotlib inline
plt.figure(figsize=[10,5])
plot_pred(model)

# %%
# %matplotlib notebook
plot_pred(model)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Building a Conv1d model

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
model_conv = Sequential()
model_conv.add(Reshape((look_back,1), input_shape = (look_back,)))
model_conv.add(Conv1D(5, 5, activation='relu'))

# %%
model_conv.add(MaxPooling1D(5))
model_conv.add(Flatten())
model_conv.add(Dense(1))
model_conv.add(Activation('linear'))
model_conv.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 10, 1)             0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 6, 5)              30
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1, 5)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 5)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_conv.compile(loss='mean_squared_error', optimizer='adam')
model_conv.fit(trainX, trainY, epochs=5, batch_size=1, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/5
# 1696/1696 - 3s - loss: 0.0311 - val_loss: 7.9729e-04
# Epoch 2/5
# 1696/1696 - 2s - loss: 0.0015 - val_loss: 8.8912e-04
# Epoch 3/5
# 1696/1696 - 2s - loss: 0.0015 - val_loss: 7.7722e-04
# Epoch 4/5
# 1696/1696 - 2s - loss: 0.0014 - val_loss: 7.7075e-04
# Epoch 5/5
# 1696/1696 - 2s - loss: 0.0014 - val_loss: 7.6528e-04

# %%
get_model_perf(model_conv)
# Out:
# Train RMSE: 0.04 RMSE
# Test RMSE: 0.04 RMSE

# %%
model_conv.evaluate(trainX,trainY,verbose=0)
# Out:
# 0.0013345204060897231

# %%
# %matplotlib inline
plt.figure(figsize=[10,5])
plot_pred(model_conv)

# %%
# %matplotlib notebook
plot_pred(model_conv)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Building a hybrid model (RNN and Conv1D)

# %%
model_comb = Sequential()
model_comb.add(Reshape((look_back,1), input_shape = (look_back,)))
model_comb.add(Conv1D(5, 3, activation='relu'))
model_comb.add(SimpleRNN(32))
model_comb.add(Dense(1))
model_comb.add(Activation('linear'))
model_comb.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 10, 1)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8, 5)              20
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 32)                1216
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,269
# Trainable params: 1,269
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_comb.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
model_comb.fit(trainX, trainY, epochs=5, batch_size=1, verbose=2, validation_split=0.1)
# Out:
# Epoch 1/5
# 1696/1696 - 7s - loss: 0.0029 - accuracy: 0.0012 - val_loss: 8.9793e-04 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1696/1696 - 7s - loss: 0.0014 - accuracy: 0.0012 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 1696/1696 - 7s - loss: 0.0012 - accuracy: 0.0012 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 1696/1696 - 6s - loss: 0.0011 - accuracy: 0.0012 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1696/1696 - 6s - loss: 0.0010 - accuracy: 0.0012 - val_loss: 3.7833e-04 - val_accuracy: 0.0000e+00

# %%
tf.keras.utils.plot_model(model_comb, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %matplotlib inline
plt.figure(figsize=[10,5])
plot_pred(model_comb)

# %%
# %matplotlib notebook
plot_pred(model_comb)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
pwd
# Out:
# 'C:\\Users\\anura'
